# %%
# !pip install pandas
# Out:
# ...
# /Users/samanthakummerer/.virtualenvs/dataj/lib/python2.7/site-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# /Users/samanthakummerer/.virtualenvs/dataj/lib/python2.7/site-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# ...

# %%
import pandas as pd
import matplotlib as mplstyle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install seaborn
# Out:
# ...
# /Users/samanthakummerer/.virtualenvs/dataj/lib/python2.7/site-packages/pip/_vendor/requests/packages/urllib3/util/ssl_.py:318: SNIMissingWarning: An HTTPS request has been made, but the SNI (Subject Name Indication) extension to TLS is not available on this platform. This may cause the server to present an incorrect TLS certificate, which can cause validation failures. You can upgrade to a newer version of Python to solve this. For more information, see https://urllib3.readthedocs.io/en/latest/security.html#snimissingwarning.
#   SNIMissingWarning
# ...

# %%
import csv
with open('/Users/samanthakummerer/Desktop/advanced-data-journalism/assignments/analysis_assignment/campus_crime.csv', 'rb') as f:
    data = list(csv.reader(f))

# %%
data = pd.read_csv('/Users/samanthakummerer/Desktop/advanced-data-journalism/assignments/analysis_assignment/campus_crime.csv')

data[:1]
# Out:
#                  instname  total_enr  murder  manslaughter  forcible  \
# 0  American River College      95250       0             0         1
#
#    nonforce  robbery  agg_aslt  burglary  vehicle  arson
# 0         2        3         2         6        8      0

# %%
data.sort_values('burglary', ascending=False)[:10]
# Out:
#                                       instname  total_enr  murder  \
# 209                       University of Toledo      67830       0
# 169       University of California-Los Angeles      39271       0
# 206      University of South Carolina-Columbia      30721       0
# 116  Pennsylvania State University-Main Campus      45628       0
# 142                     Stony Brook University      23920       0
# 210                         University of Utah      31660       0
# 1                     Arizona State University     289016       0
# 69              Indiana University-Bloomington      42731       0
# 167             University of California-Davis      63464       0
# 91                   Michigan State University     191300       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 209             0         2         0        1         4       118        0
# 169             0         8         0        2         4       118        7
# ...

# %%
smaller_data = data[data.burglary < 80]

g = sns.FacetGrid(data, size=7)

g.map(plt.scatter, "burglary", "robbery", alpha=.8)

# %%
data[(data.total_enr >= 100000) & (data.total_count <= 3)].sort_values('total_count')
# Out:
#                                       instname  total_enr  murder  \
# 38                   DeVry University-Illinois     279210       0
# 122                         Rio Salado College     251090       0
# 143           Suffolk County Community College     107148       0
# 27            Columbus State Community College     247368       0
# 190  University of Maryland-University College     256278       0
# 37           Des Moines Area Community College     279675       0
# 137                 Sinclair Community College     105530       0
# 141                      St Petersburg College     265024       0
# 4            Austin Community College District    1082400       0
# 74                    Johns Hopkins University     209960       0
# 113                   Palm Beach State College     117416       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 38              0         0         0        0         0         0        0
# ...
